# %%
import pandas as pd
import requests
import numpy as np
from bs4 import BeautifulSoup

# %%
headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
webpage=requests.get('https://www.ambitionbox.com/list-of-companies?page=1',headers=headers).text

# %%
soup=BeautifulSoup(webpage)

# %%
for i in soup.find_all('h2', class_="companyCardWrapper__companyName"):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited

# %%
for i in soup.find_all('h2', class_="companyCardWrapper__companyName"):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited

# %%
for i in soup.find_all('h2', class_="companyCardWrapper__companyName"):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited

# %%
for i in soup.find_all('h2', class_="companyCardWrapper__companyName"):
    print(i.text.strip())
# Out:
# TCS
# Accenture
# Cognizant
# Wipro
# Capgemini
# HDFC Bank
# ICICI Bank
# Infosys
# HCLTech
# Tech Mahindra
# Genpact
# Axis Bank
# Teleperformance
# Concentrix Corporation
# Jio
# Amazon
# IBM
# Reliance Retail
# HDB Financial Services
# Larsen & Toubro Limited

# %%
for i in soup.find_all('span', class_="companyCardWrapper__companyRatingValue"):
    print(i.text)
# Out:
# 3.8
# 4.0
# 3.9
# 3.8
# 3.9
# 4.0
# 4.0
# 3.8
# 3.7
# 3.7
# 3.9
# 3.9
# 3.6
# 3.9
# 4.0
# 4.1
# 4.1
# 4.0
# 4.0
# 4.1

# %%
len(soup.find_all('span', class_="companyCardWrapper__companyRatingValue"))
# Out:
# 20

# %%
company=soup.find_all('div',class_="companyCardWrapper")

# %%
name = []
knownfor = []
rating = []
reviews = []
jobs = []
benefits = []

for i in company:
    name.append(i.find('h2').text.strip())
    knownfor.append(i.find('span', class_="companyCardWrapper__ratingValues").text.strip())
    rating.append(i.find('span', class_="companyCardWrapper__companyRatingValue").text.strip())
    reviews.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[0].text.strip())
    jobs.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[3].text.strip())
    benefits.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[4].text.strip())

d={'name': name, 'Known_for': knownfor, 'rating':rating, 'reviews': reviews, 'jobs': jobs, 'benefits':benefits}
df = pd.DataFrame(d)

# %%
company[0].find_all('span', class_="companyCardWrapper__ActionCount")[0].text.strip()
# Out:
# '73.3k'

# %%
knownfor
# Out:
# ['Job Security, Work Life Balance',
#  'Company Culture, Skill Development / Learning, Job Security',
#  'Skill Development / Learning',
#  'Job Security',
#  'Job Security, Work Life Balance, Skill Development / Learning',
#  'Job Security, Skill Development / Learning',
#  'Job Security, Skill Development / Learning, Company Culture',
#  'Job Security, Company Culture, Skill Development / Learning',
#  'Job Security',
#  'Promotions / Appraisal, Salary & Benefits',
#  'Job Security, Skill Development / Learning, Work Life Balance',
#  'Job Security',
#  'Promotions / Appraisal, Salary & Benefits, Work Satisfaction',
#  'Job Security, Company Culture',
#  'Job Security, Skill Development / Learning',
#  'Company Culture, Salary & Benefits, Work Life Balance',
#  'Work Life Balance, Job Security, Skill Development / Learning',
#  'Skill Development / Learning, Job Security',
#  'Skill Development / Learning, Job Security, Company Culture',
# ...

# %%
df
# Out:
#                        name  \
# 0                       TCS
# 1                 Accenture
# 2                 Cognizant
# 3                     Wipro
# 4                 Capgemini
# 5                 HDFC Bank
# 6                ICICI Bank
# 7                   Infosys
# 8                   HCLTech
# 9             Tech Mahindra
# 10                  Genpact
# 11                Axis Bank
# 12          Teleperformance
# 13   Concentrix Corporation
# 14                      Jio
# 15                   Amazon
# 16                      IBM
# 17          Reliance Retail
# 18   HDB Financial Services
# 19  Larsen & Toubro Limited
#
#                                             Known_for rating reviews   jobs  \
# 0                     Job Security, Work Life Balance    3.8   73.3k    924
# 1   Company Culture, Skill Development / Learning,...    4.0   46.5k  13.1k
# 2                        Skill Development / Learning    3.9   41.8k    454
# ...

# %%
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
final=pd.DataFrame()
for j in range(1,350):

    url = 'https://www.ambitionbox.com/list-of-companies?page={}'.format(j)
    headers={'User-Agent':'Mozilla/5.0 (Windows NT 6.3; Win 64 ; x64) Apple WeKit /537.36(KHTML , like Gecko) Chrome/80.0.3987.162 Safari/537.36'} 
    webpage=requests.get(url,headers=headers).text
    soup=BeautifulSoup(webpage)
    company=soup.find_all('div',class_="companyCardWrapper")
    name = []
    knownfor = []
    rating = []
    reviews = []
    jobs = []
    benefits = []
    
    for i in company:
        name.append(i.find('h2').text.strip())
        try:
            knownfor.append(i.find('span', class_="companyCardWrapper__ratingValues").text.strip())
        except:
            knownfor.append(np.nan)
        rating.append(i.find('span', class_="companyCardWrapper__companyRatingValue").text.strip())
        reviews.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[0].text.strip())
        jobs.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[3].text.strip())
        benefits.append(i.find_all('span', class_="companyCardWrapper__ActionCount")[4].text.strip())
        d={'name': name, 'Known_for': knownfor, 'rating':rating, 'reviews': reviews, 'jobs': jobs, 'benefits':benefits}
        df = pd.DataFrame(d)
        final =  pd.concat([final,df],ignore_index=True)

# %%
final
# Out:
#                       name                                          Known_for  \
# 0                      TCS                    Job Security, Work Life Balance
# 1                      TCS                    Job Security, Work Life Balance
# 2                Accenture  Company Culture, Skill Development / Learning,...
# 3                      TCS                    Job Security, Work Life Balance
# 4                Accenture  Company Culture, Skill Development / Learning,...
# ...                    ...                                                ...
# 73285  Thoughtsol Infotech  Company Culture, Skill Development / Learning,...
# 73286         D A V School  Work Satisfaction, Skill Development / Learnin...
# 73287    Maheshwari Mining  Promotions / Appraisal, Salary & Benefits, Com...
# 73288       Mantra Softech                 Company Culture, Work Life Balance
# 73289    Zeon Lifesciences  Promotions / Appraisal, Salary & Benefits, Ski...
#
# ...

# %%
final.drop_duplicates(inplace=True)

# %%
final.to_csv('company_data_final.csv')

# %%
final.reset_index(inplace = True, drop = True)

# %%
final.to_csv('company_data_final.csv')
